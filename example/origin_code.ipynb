# %% [markdown]
# # 1. test data

# %% [markdown]
# ## 1.1 init

# %%
import pandas as pd
import sys
sys.path.append('C:/ProgramData/Anaconda3/Lib/site-packages')
import ERgene

# %%
import matplotlib.pyplot as plt
data=pd.read_csv('test.csv')
font1 = {
'weight' : 'bold',
'size'   : 18,
}
data.plot(kind = 'density')
plt.xlim(-1000,1000)
# Out:
# (-1000, 1000)

# %%
data.plot(kind = 'box')
plt.ylim(-200,800)
# Out:
# (-200, 800)

# %% [markdown]
# ## 1.2 Find ERgene

# %%
ERgene.FindERG(data)
# Out:
# calculate time:2.04s
# ['Q6PIC6', 'A3KGU7', 'Q03265', 'P63260', 'O08553', 'Q62261', 'P63101', 'Q68FG2', 'P05064', 'P17182', 'A0A1D5RLD8', 'Q7TMM9', 'Q9QYR6', 'Q9JHU4', 'Q04447', 'P46660', 'P50516', 'S4R2F3', 'P17742', 'P56480']

# %% [markdown]
# ## 1.3 normalizationdata

# %%
data2=ERgene.normalizationdata(data,'Q6PIC6')

# %%
data2.plot(kind = 'density')
plt.xlim(-1000,1000)
# Out:
# (-1000, 1000)

# %%
data2.plot(kind = 'box')
plt.ylim(-200,800)
# Out:
# (-200, 800)
